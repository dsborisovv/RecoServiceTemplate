# %% [markdown]
# # Connect google drive

# %%
from google.colab import drive

drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Install requirements

# %% [markdown]
# Install req from lecture 2 repo

# %%
# !pip install -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt
# Out:
# Collecting appnope==0.1.3 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 1))
#   Downloading appnope-0.1.3-py2.py3-none-any.whl (4.4 kB)
# Collecting asttokens==2.4.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 2))
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: attrs==23.1.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 4)) (2023.7.22)
# Requirement already satisfied: charset-normalizer==3.3.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 5)) (3.3.2)
# Collecting comm==0.2.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 6))
#   Downloading comm-0.2.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: contourpy==1.2.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 8)) (0.12.1)
# Collecting debugpy==1.8.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 9))
#   Downloading debugpy-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 38.3 MB/s eta 0:00:00
# Collecting decorator==5.1.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 10))
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: exceptiongroup==1.1.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 11)) (1.1.3)
# Collecting executing==2.0.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 12))
#   Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Collecting fastjsonschema==2.18.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 13))
#   Downloading fastjsonschema-2.18.1-py3-none-any.whl (23 kB)
# Collecting fonttools==4.44.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 14))
#   Downloading fonttools-4.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 67.4 MB/s eta 0:00:00
# Requirement already satisfied: idna==3.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 15)) (3.4)
# Collecting implicit==0.7.2 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 16))
#   Downloading implicit-0.7.2-cp310-cp310-manylinux2014_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 88.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata==6.8.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 17)) (6.8.0)
# Requirement already satisfied: importlib-resources==6.1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 18)) (6.1.1)
# Collecting ipykernel==6.26.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 19))
#   Downloading ipykernel-6.26.0-py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 kB 13.3 MB/s eta 0:00:00
# Collecting ipython==8.17.2 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 20))
#   Downloading ipython-8.17.2-py3-none-any.whl (808 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.4/808.4 kB 58.9 MB/s eta 0:00:00
# Collecting ipywidgets==8.1.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 21))
#   Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 14.3 MB/s eta 0:00:00
# Collecting jedi==0.19.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 22))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.6 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema==4.19.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 23)) (4.19.2)
# Collecting jsonschema-specifications==2023.7.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 24))
#   Downloading jsonschema_specifications-2023.7.1-py3-none-any.whl (17 kB)
# Collecting jupyter_client==8.6.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 25))
#   Downloading jupyter_client-8.6.0-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: jupyter_core==5.5.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 26)) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets==3.0.9 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 27)) (3.0.9)
# Requirement already satisfied: kiwisolver==1.4.5 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 28)) (1.4.5)
# Requirement already satisfied: llvmlite==0.41.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 29)) (0.41.1)
# Collecting matplotlib==3.8.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 30))
#   Downloading matplotlib-3.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 74.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib-inline==0.1.6 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 31)) (0.1.6)
# Requirement already satisfied: nbformat==5.9.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 32)) (5.9.2)
# Requirement already satisfied: nest-asyncio==1.5.8 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 33)) (1.5.8)
# Requirement already satisfied: numba==0.58.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 34)) (0.58.1)
# Collecting numpy==1.26.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 35))
#   Downloading numpy-1.26.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 54.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging==23.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 36)) (23.2)
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 37)) (1.5.3)
# Requirement already satisfied: parso==0.8.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 38)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 39)) (4.8.0)
# Collecting Pillow==10.1.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 40))
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 77.2 MB/s eta 0:00:00
# Collecting platformdirs==3.11.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 41))
#   Downloading platformdirs-3.11.0-py3-none-any.whl (17 kB)
# Collecting plotly==5.18.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 42))
#   Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 60.0 MB/s eta 0:00:00
# Collecting prompt-toolkit==3.0.39 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 43))
#   Downloading prompt_toolkit-3.0.39-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 kB 34.4 MB/s eta 0:00:00
# Collecting psutil==5.9.6 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 44))
#   Downloading psutil-5.9.6-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 45)) (0.7.0)
# Collecting pure-eval==0.2.2 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 46))
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: Pygments==2.16.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 47)) (2.16.1)
# Requirement already satisfied: pyparsing==3.1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 48)) (3.1.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 49)) (2.8.2)
# Requirement already satisfied: pytz==2023.3.post1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 50)) (2023.3.post1)
# Collecting pyzmq==25.1.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 51))
#   Downloading pyzmq-25.1.1-cp310-cp310-manylinux_2_28_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.0 MB/s eta 0:00:00
# Collecting rectools==0.4.1 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 52))
#   Downloading rectools-0.4.1-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 12.0 MB/s eta 0:00:00
# Collecting referencing==0.30.2 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 53))
#   Downloading referencing-0.30.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 54)) (2.31.0)
# Collecting rpds-py==0.12.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 55))
#   Downloading rpds_py-0.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy==1.11.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 56)) (1.11.3)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 57)) (1.16.0)
# Collecting stack-data==0.6.3 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 58))
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: tenacity==8.2.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 59)) (8.2.3)
# Requirement already satisfied: threadpoolctl==3.2.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 60)) (3.2.0)
# Collecting tornado==6.3.3 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 61))
#   Downloading tornado-6.3.3-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.7/427.7 kB 35.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm==4.66.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 62)) (4.66.1)
# Collecting traitlets==5.13.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 63))
#   Downloading traitlets-5.13.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.9 MB/s eta 0:00:00
# Collecting typeguard==2.13.3 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 64))
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting typing_extensions==4.8.0 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 65))
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: urllib3==2.0.7 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 66)) (2.0.7)
# Collecting wcwidth==0.2.9 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 67))
#   Downloading wcwidth-0.2.9-py2.py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 kB 11.1 MB/s eta 0:00:00
# Collecting widgetsnbextension==4.0.9 (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 68))
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 71.7 MB/s eta 0:00:00
# Requirement already satisfied: zipp==3.17.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/itmo_recsys/lesson_2/requirements.txt (line 69)) (3.17.0)
# Installing collected packages: wcwidth, pure-eval, fastjsonschema, appnope, widgetsnbextension, typing_extensions, typeguard, traitlets, tornado, rpds-py, pyzmq, psutil, prompt-toolkit, plotly, platformdirs, Pillow, numpy, jedi, fonttools, executing, decorator, debugpy, asttokens, stack-data, referencing, comm, matplotlib, jupyter_client, jsonschema-specifications, ipython, implicit, rectools, ipywidgets, ipykernel
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.10
#     Uninstalling wcwidth-0.2.10:
#       Successfully uninstalled wcwidth-0.2.10
#   Attempting uninstall: fastjsonschema
#     Found existing installation: fastjsonschema 2.19.0
#     Uninstalling fastjsonschema-2.19.0:
#       Successfully uninstalled fastjsonschema-2.19.0
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.2
#     Uninstalling tornado-6.3.2:
#       Successfully uninstalled tornado-6.3.2
#   Attempting uninstall: rpds-py
#     Found existing installation: rpds-py 0.13.0
#     Uninstalling rpds-py-0.13.0:
#       Successfully uninstalled rpds-py-0.13.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.1
#     Uninstalling pyzmq-23.2.1:
#       Successfully uninstalled pyzmq-23.2.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.41
#     Uninstalling prompt-toolkit-3.0.41:
#       Successfully uninstalled prompt-toolkit-3.0.41
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.0.0
#     Uninstalling platformdirs-4.0.0:
#       Successfully uninstalled platformdirs-4.0.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.44.3
#     Uninstalling fonttools-4.44.3:
#       Successfully uninstalled fonttools-4.44.3
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.6.6
#     Uninstalling debugpy-1.6.6:
#       Successfully uninstalled debugpy-1.6.6
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.31.0
#     Uninstalling referencing-0.31.0:
#       Successfully uninstalled referencing-0.31.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: jupyter_client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jsonschema-specifications
#     Found existing installation: jsonschema-specifications 2023.11.1
#     Uninstalling jsonschema-specifications-2023.11.1:
#       Successfully uninstalled jsonschema-specifications-2023.11.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# cupy-cuda11x 11.0.0 requires numpy<1.26,>=1.20, but you have numpy 1.26.1 which is incompatible.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.26.0 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.17.2 which is incompatible.
# google-colab 1.0.0 requires tornado==6.3.2, but you have tornado 6.3.3 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# notebook 6.5.5 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.6.0 which is incompatible.
# notebook 6.5.5 requires pyzmq<25,>=17, but you have pyzmq 25.1.1 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed Pillow-10.1.0 appnope-0.1.3 asttokens-2.4.1 comm-0.2.0 debugpy-1.8.0 decorator-5.1.1 executing-2.0.1 fastjsonschema-2.18.1 fonttools-4.44.0 implicit-0.7.2 ipykernel-6.26.0 ipython-8.17.2 ipywidgets-8.1.1 jedi-0.19.1 jsonschema-specifications-2023.7.1 jupyter_client-8.6.0 matplotlib-3.8.1 numpy-1.26.1 platformdirs-3.11.0 plotly-5.18.0 prompt-toolkit-3.0.39 psutil-5.9.6 pure-eval-0.2.2 pyzmq-25.1.1 rectools-0.4.1 referencing-0.30.2 rpds-py-0.12.0 stack-data-0.6.3 tornado-6.3.3 traitlets-5.13.0 typeguard-2.13.3 typing_extensions-4.8.0 wcwidth-0.2.9 widgetsnbextension-4.0.9

# %% [markdown]
# # Imports

# %%
import time
from pprint import pprint
from typing import Tuple

import numpy as np
import pandas as pd
import rectools
from rectools import Columns
from rectools.dataset import Dataset, Interactions
from rectools.metrics import (MAP, NDCG, MeanInvUserFreq, Precision, Recall,
                              Serendipity, calc_metrics)
from rectools.model_selection import TimeRangeSplitter
from rectools.models import (ImplicitItemKNNWrapperModel, PopularModel,
                             RandomModel)
from tqdm.auto import tqdm

N_FOLDS = 3
RANDOM_STATE = 32
K_RECS = 10
USERS = [666262, 672861, 955527]

# %% [markdown]
# # Get datasets

# %%
interactions = pd.read_csv(
    "/content/drive/MyDrive/itmo_recsys/kion_dataset/interactions.csv",
    parse_dates=["last_watch_dt"],
)
items = pd.read_csv("/content/drive/MyDrive/itmo_recsys/kion_dataset/items.csv")

interactions.rename(
    columns={"last_watch_dt": Columns.Datetime, "total_dur": Columns.Weight},
    inplace=True,
)

# %%
interactions.head()
# Out:
#    user_id  item_id   datetime  weight  watched_pct
# 0   176549     9506 2021-05-11    4250         72.0
# 1   699317     1659 2021-05-29    8317        100.0
# 2   656683     7107 2021-05-09      10          0.0
# 3   864613     7638 2021-07-05   14483        100.0
# 4   964868     9506 2021-04-30    6725        100.0

# %% [markdown]
# # Calculate metrics

# %%
def calculate_metrics(
    models: dict,
    metrics: dict,
    cv: TimeRangeSplitter,
    k_recs: int,
    interactions: pd.DataFrame,
) -> Tuple[list, pd.DataFrame]:
    results = []
    interactions = Interactions(interactions)
    fold_iterator = cv.split(interactions, collect_fold_stats=True)
    for train_ids, test_ids, fold_info in tqdm((fold_iterator), total=3):
        print(f"\n==================== Fold {fold_info['i_split']}")
        pprint(fold_info)

        df_train = interactions.df.iloc[train_ids]
        dataset = Dataset.construct(df_train)

        df_test = interactions.df.iloc[test_ids][Columns.UserItem]
        test_users = np.unique(df_test[Columns.User])

        catalog = df_train[Columns.Item].unique()

        for model_name, model in models.items():
            start_time = time.time()
            model.fit(dataset)
            end_time = time.time()
            recos = model.recommend(
                users=test_users,
                dataset=dataset,
                k=k_recs,
                filter_viewed=True,
            )
            metric_values = calc_metrics(
                metrics,
                reco=recos,
                interactions=df_test,
                prev_interactions=df_train,
                catalog=catalog,
            )
            res = {"fold": fold_info["i_split"], "model": model_name}
            res.update(metric_values)
            res.update({"time_seconds": end_time - start_time})
            results.append(res)
    results_pd = pd.DataFrame(results)

    return results, results_pd

# %%
cv = TimeRangeSplitter(
    test_size="7D",
    n_splits=N_FOLDS,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)

models = {"random": RandomModel(random_state=RANDOM_STATE), "popular": PopularModel()}

metrics = {
    "prec@1": Precision(k=1),
    "prec@5": Precision(k=5),
    "prec@10": Precision(k=10),
    "recall@1": Recall(k=1),
    "recall@5": Recall(k=5),
    "recall@10": Recall(k=10),
    "map@1": MAP(k=1),
    "map@5": MAP(k=5),
    "map@10": MAP(k=10),
    "ndcg@1": NDCG(k=1),
    "ndcg@5": NDCG(k=5),
    "ndcg@10": NDCG(k=10),
    "novelty@1": MeanInvUserFreq(k=1),
    "novelty@5": MeanInvUserFreq(k=5),
    "novelty@10": MeanInvUserFreq(k=10),
    "serendipity@1": Serendipity(k=1),
    "serendipity@5": Serendipity(k=5),
    "serendipity@10": Serendipity(k=10),
}

# %%
results, results_pd = calculate_metrics(
    models=models, metrics=metrics, cv=cv, k_recs=K_RECS, interactions=interactions
)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ==================== Fold 0
# {'end': Timestamp('2021-08-09 00:00:00', freq='7D'),
#  'i_split': 0,
#  'start': Timestamp('2021-08-02 00:00:00', freq='7D'),
#  'test': 263681,
#  'test_items': 6602,
#  'test_users': 98184,
#  'train': 4266013,
#  'train_items': 15237,
#  'train_users': 797423}
#
# ==================== Fold 1
# {'end': Timestamp('2021-08-16 00:00:00', freq='7D'),
#  'i_split': 1,
#  'start': Timestamp('2021-08-09 00:00:00', freq='7D'),
#  'test': 279422,
#  'test_items': 6698,
#  'test_users': 103511,
#  'train': 4649162,
#  'train_items': 15415,
#  'train_users': 850489}
#
# ==================== Fold 2
# {'end': Timestamp('2021-08-23 00:00:00', freq='7D'),
#  'i_split': 2,
#  'start': Timestamp('2021-08-16 00:00:00', freq='7D'),
#  'test': 298878,
#  'test_items': 6679,
#  'test_users': 110076,
#  'train': 5051815,
#  'train_items': 15577,
#  'train_users': 906071}

# %%
agg_dict = dict(zip(list(metrics.keys()), ["mean" for _ in range(len(metrics.keys()))]))

mean_results = results_pd.groupby("model", as_index=False).agg(agg_dict)

mean_time = results_pd.groupby("model", as_index=False).agg({"time_seconds": "mean"})

# %%
mean_results
# Out:
#      model    prec@1    prec@5   prec@10  recall@1  recall@5  recall@10  \
# 0  popular  0.076432  0.052402  0.033903  0.042720  0.137413   0.173492
# 1   random  0.000221  0.000202  0.000193  0.000072  0.000365   0.000693
#
#       map@1     map@5    map@10    ndcg@1    ndcg@5   ndcg@10  novelty@1  \
# 0  0.042720  0.078295  0.084109  0.076432  0.057932  0.043084   2.377055
# 1  0.000072  0.000169  0.000211  0.000221  0.000208  0.000200  15.614137
#
#    novelty@5  novelty@10  serendipity@1  serendipity@5  serendipity@10
# 0   3.066979    3.713390       0.000002       0.000003        0.000002
# 1  15.612989   15.613009       0.000006       0.000007        0.000007

# %%
mean_time
# Out:
#      model  time_seconds
# 0  popular      2.659522
# 1   random      0.000059

# %% [markdown]
# # Visual analysis

# %%
def visual_analysis(
    model: rectools.models,
    interactions: pd.DataFrame,
    dataset: rectools.dataset,
    users: list,
    item_data: pd.DataFrame,
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    recos = model.recommend(
        users=interactions[Columns.User].unique(),
        dataset=dataset,
        k=10,
        filter_viewed=True,
    )

    user_viewed_all = pd.DataFrame()
    user_recos_all = pd.DataFrame()

    for user in users:
        user_viewed = interactions.query(f"user_id == {user}").merge(
            item_data, on="item_id"
        )
        user_recos = recos.query(f"user_id == {user}").merge(item_data, on="item_id")
        user_viewed_all = pd.concat([user_viewed_all, user_viewed], axis=0)
        user_recos_all = pd.concat([user_recos_all, user_recos], axis=0)

    return user_viewed_all, user_recos_all

# %% [markdown]
# Calculate count of views for each item_id

# %%
count_of_views = (
    interactions.groupby("item_id", as_index=False)
    .agg({"user_id": "count"})
    .rename(columns={"user_id": "count_of_views"})
)

# %%
items = items.merge(count_of_views, left_on="item_id", right_on="item_id", how="inner")

# %% [markdown]
# For example, train simple model

# %%
simple_model = PopularModel()
dataset = Dataset.construct(interactions)
simple_model.fit(dataset)

user_viewed_all, user_recos_all = visual_analysis(
    model=simple_model,
    interactions=interactions,
    dataset=dataset,
    users=USERS,
    item_data=items,
)

# %%
user_viewed_all = user_viewed_all[
    ["user_id", "item_id", "datetime", "title", "genres", "count_of_views"]
]
user_recos_all = user_recos_all[
    ["user_id", "item_id", "score", "rank", "title", "genres", "count_of_views"]
]

# %%
user_viewed_all.head()
# Out:
#    user_id  item_id   datetime                 title  \
# 0   666262     7957 2021-05-12      Последний викинг
# 1   666262     4785 2021-05-12     Робин Гуд: Начало
# 2   666262    12981 2021-05-14               Томирис
# 0   672861     6870 2021-04-27  Красавица и чудовище
# 1   672861     8662 2021-05-04           Он – дракон
#
#                                   genres  count_of_views
# 0     боевики, историческое, приключения             746
# 1         боевики, триллеры, приключения             485
# 2  боевики, драмы, историческое, военные           10370
# 0            драмы, фэнтези, музыкальные            1083
# 1                                фэнтези             643

# %%
user_recos_all.head()
# Out:
#    user_id  item_id     score  rank                   title  \
# 0   666262    10440  202457.0     1             Хрустальный
# 1   666262    15297  193123.0     2         Клиника счастья
# 2   666262     9728  132865.0     3       Гнев человеческий
# 3   666262    13865  122119.0     4                Девятаев
# 4   666262     4151   91167.0     5  Секреты семейной жизни
#
#                         genres  count_of_views
# 0          триллеры, детективы          202457
# 1             драмы, мелодрамы          193123
# 2            боевики, триллеры          132865
# 3  драмы, военные, приключения          122119
# 4                      комедии           91167
